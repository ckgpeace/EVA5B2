# %% [markdown]
# <a href="https://colab.research.google.com/github/ckgpeace/EVA5B2/blob/main/S13/S13_YoloV3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing the important libraries

# %%
import pandas as pd
import os as os
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ### Mount drive to colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd /content/drive/MyDrive/EVA5/EVA5B2/S13/
# Out:
# /content/drive/MyDrive/EVA5/EVA5B2/S13

# %%
ls
# Out:
# YoloV3/

# %% [markdown]
# ### Clone YoloV3 github repo of **TheSchoolofAI**

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git

# %%
ls
# Out:
# YoloV3/

# %%
cd YoloV3/
# Out:
# /content/drive/MyDrive/EVA5/EVA5B2/S13/YoloV3

# %%
ls
# Out:
#  annotation_tool/   __pycache__/   test1_infrd/      'ubdivisions=1'
#  cfg/               README.md      test_batch0.png    utils/
#  data/              results.json   test.py            vim.exe.stackdump
#  detect.py          results.png    ting               weights/
#  models.py          results.txt    train_batch0.png
#  output/            runs/          train.py

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.8.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
pwd
# Out:
# '/content/drive/MyDrive/EVA5/EVA5B2/S13/YoloV3'

# %% [markdown]
# ### Train your custom dataset
# 1. Check the parameters and make sure they are valid
# 2. 'yolov3-s13.cfg' is my configuration file and you put yours in the required directory

# %%
# !python train.py --data data/assignment13/custom.data --batch 10 --cache --cfg cfg/yolov3-s13.cfg --epochs 25 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-s13.cfg', data='data/assignment13/custom.data', device='', epochs=25, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2021-03-20 19:19:16.601696: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# ...

# %% [markdown]
# ### Infer your custom dataset
# 1. You can infer your own datasets with script
# 2. '--conf-thres' is the threshold to detect object and its based on use case, higher more confident BB detection
# 3. Check the '.cfg' file
# 4. '--source' folder path of images for inference

# %%
# !python detect.py --conf-thres 0.3 --cfg cfg/yolov3-s13.cfg --name data/assignment13/custom.names --source data/assignment13/test1 --output test1_infrd
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-s13.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/assignment13/custom.names', output='test1_infrd', save_txt=False, source='data/assignment13/test1', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/801 data/assignment13/test1/dance-0001.png: 512x512 6 hardhats, 1 vests, Done. (0.020s)
# image 2/801 data/assignment13/test1/dance-0002.png: 512x512 6 hardhats, 1 vests, Done. (0.020s)
# image 3/801 data/assignment13/test1/dance-0003.png: 512x512 6 hardhats, 1 vests, Done. (0.020s)
# image 4/801 data/assignment13/test1/dance-0004.png: 512x512 6 hardhats, 1 vests, Done. (0.020s)
# image 5/801 data/assignment13/test1/dance-0005.png: 512x512 9 hardhats, 1 bootss, Done. (0.020s)
# ...
