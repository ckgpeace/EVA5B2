# %% [markdown]
# <a href="https://colab.research.google.com/github/ckgpeace/EVA5B2/blob/main/S15A/S15A_Midas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/EVA5/Assignment15A
# Out:
# /content/drive/MyDrive/EVA5/Assignment15A

# %%
pwd
# Out:
# '/content/drive/MyDrive/EVA5/Assignment15A'

# %%
# !git clone https://github.com/intel-isl/MiDaS.git
# Out:
# Cloning into 'MiDaS'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 394 (delta 58), reused 202 (delta 36), pack-reused 144
# Receiving objects: 100% (394/394), 231.04 KiB | 3.25 MiB/s, done.
# Resolving deltas: 100% (139/139), done.
# Checking out files: 100% (131/131), done.

# %%
ls
# Out:
# data/  MiDaS/  planercnn/

# %%
cd MiDaS
# Out:
# /content/drive/My Drive/EVA5/Assignment15A/MiDaS

# %%
ls
# Out:
# Dockerfile  input/   midas/   output/    ros/    tf/
# hubconf.py  LICENSE  mobile/  README.md  run.py  utils.py

# %%
# !pip install pytorch torchvision opencv
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %%
#Run Example image in 'input' folder
# !python run.py
# Out:
# initialize
# device: cuda
# Loading weights:  model-f6b98070.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:03<00:00, 103MB/s]
# start processing
#   processing input/vestMask0.jpg (1/1)
# finished

# %%
#Run Example image in 'input' folder
# !python run.py --input_path '/content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images' --output_path '/content/drive/MyDrive/EVA5/Assignment15A/MiDaS/midas_out'
# Out:
# initialize
# device: cuda
# Loading weights:  model-f6b98070.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_master
# start processing
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/K123.jpg (1/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/K150.jpg (2/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/K195.jpg (3/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/K230.jpg (4/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/Ktt.jpg (5/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/Kt.jpg (6/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/K226.jpg (7/3590)
#   processing /content/drive/MyDrive/EVA5/Assignment15A/data/assignment13/images/Kyy.jpg (8/3590)
# ...

# %%
ls
# Out:
# Dockerfile  LICENSE     mobile/                  output/       ros/    utils.py
# hubconf.py  midas/      model-f6b98070.pt        __pycache__/  run.py
# input/      midas_out/  model-small-70d6b9c8.pt  README.md     tf/

# %%
# !rm -r MiDaS_out/

# %%
# ! du -sh /content/drive/My\ Drive/<folder-name>
! du -sh midas_out/
# Out:
# 5.3G	midas_out/

# %%
# !zip -r midas_out.zip midas_out/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: midas_out/R6.pfm (deflated 75%)
#   adding: midas_out/R6.png (deflated 6%)
#   adding: midas_out/R78.pfm (deflated 80%)
#   adding: midas_out/R78.png (deflated 9%)
#   adding: midas_out/R34.pfm (deflated 78%)
#   adding: midas_out/R34.png (deflated 7%)
#   adding: midas_out/R23.pfm (deflated 78%)
#   adding: midas_out/R23.png (deflated 7%)
#   adding: midas_out/R54.pfm (deflated 77%)
#   adding: midas_out/R54.png (deflated 7%)
#   adding: midas_out/R36.pfm (deflated 76%)
#   adding: midas_out/R36.png (deflated 8%)
#   adding: midas_out/R96.pfm (deflated 85%)
#   adding: midas_out/R96.png (deflated 11%)
#   adding: midas_out/images12.pfm (deflated 67%)
#   adding: midas_out/images12.png (deflated 2%)
#   adding: midas_out/images209.pfm (deflated 70%)
#   adding: midas_out/images209.png (deflated 4%)
#   adding: midas_out/images585.pfm (deflated 64%)
#   adding: midas_out/images585.png (deflated 3%)
# ...

# %%
from zipfile import ZipFile
# Create a ZipFile Object and load sample.zip in it
with ZipFile('/content/drive/MyDrive/EVA5/Assignment15A/MiDaS/midas_out.zip', 'r') as zipObj:
   # Get list of files names in zip
   listOfiles = zipObj.namelist()
   # Iterate over the list of file names in given list & print them
   print(len(listOfiles)/2)
# Out:
# 3590.5

# %%
# rm -r /content/drive/MyDrive/EVA5/Assignment15A/MiDaS/midas_out
# Out:
# rm: cannot remove '/content/drive/MyDrive/EVA5/Assignment15A/MiDaS/midas_out': No such file or directory
